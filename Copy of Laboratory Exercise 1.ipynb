# %% [markdown]
# <ul><font size = 5 color='Orange'>
# Learning Goals</font>
# <font color = 'Orange'><li>Understand the structure of a web page.</li>
# <li>Understand how to use Beautiful soup to scrape content from web pages.</li>
# <li>Feel comfortable storing and manipulating the content in various formats.</li>
# <li>Understand how to convert structured format into a Pandas DataFrame.</li>
# </font>
# </ul>

# %% [markdown]
# <font size = 4 color = "green">For this homework your job is to find a web-site from which you will extract the data, we are suggestioning for a local-site like time.mk, sitel.mk, vecer.mk, panacea.mk, reklama5.mk, etc. Accordinly with the choice you've made make a quick summary why did you use especially this web-site and what is the part of interest.</font>

# %% [markdown]
# #<font color = 'Orange'>Explain the Web-site that you will be using in this homework.</font>

# %% [markdown]
# In the following text-box answer the questions:
# <li>What data you will be extracting and why?</li>
# <li>Add a screenshot of the web-site that you will be scraping</li>

# %% [markdown]
#  add your answers here

# %% [markdown]
# # <font color='Orange'>Requirements specified for Web Scraping</font>

# %% [markdown]
# Import all libraries and modules that you are going to use.

# %%
#start here
#shift+enter in this box will run the code that's here and open a new code-box below
#import ....
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
from IPython.display import HTML
import warnings

# %% [markdown]
# # <font color = 'Orange'> Start the scraping by sending HTTP request</font>

# %% [markdown]
#  **Fetch a website's content - send request**

# %%
#add your code
snapshot_url = 'https://reklama5.mk/'
snapshot = requests.get(snapshot_url)

# %% [markdown]
# **Get the response-status code and see:**
# <li>If the code starts with a 2, it means the request was successful.

# %%
#add your code
snapshot
# Out:
# <Response [200]>

# %% [markdown]
# # <font color = 'orange'>Parse the HTML with BeautifulSoup</font>

# %% [markdown]
# Beautiful Soup is a Python library for pulling data out of HTML and XML files. It works with your favorite parser to provide idiomatic ways of navigating, searching, and modifying the parse tree. It commonly saves programmers hours or days of work.

# %% [markdown]
# **Parse using BeautifulSoap**

# %%
#add your code
raw_html = snapshot.text;
soup = BeautifulSoup(raw_html,'html.parser')

# %% [markdown]
# **Print the HTML code that you get**

# %%
#add your code
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>Oglasi | Reklama5.mk | Огласи | Автомобили | Недвижнини | Компјутери | Мобилн телефони | Услуги,Бизнис | Вработување | Реклами |</title>
# <link href="/favicon.ico" rel="SHORTCUT ICON" type="image/vnd.microsoft.icon"/>
# <link href="/favicon.ico" rel="icon" type="image/png"/>
# <link href="/Content/css?v=QzLaHFBXrcD9k4hYZ0RklDOj_h-UXqxeZ7UhHn-RUdE1" rel="stylesheet">
# <link href="/Content/Sidebar.css" rel="stylesheet" type="text/css"/>
# <script src="/bundles/modernizr?v=wBEWDufH_8Md-Pbioxomt90vm6tJN2Pyy9u9zHtWsPo1"></script>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#             var cookieDomain = '.reklama5.mk';
#     </script>
# <script>
#             var googletag = googletag || {};
#             googletag.cmd = googletag.cmd || [];
#         </script>
# <script>
#             googletag.cmd.push(function () {
#                 googletag.defineSlot('/21619973618/home-top-banner-970x90', [[970, 90], [970, 240], [970, 120]], 'div-gpt-ad-1505228250182-0').addService(googletag.pubads());
#                 googletag.pubads().collapseEmptyDivs();
#                 googletag.enableServices();
#             });
#         </script>
# <script type="text/javascript">
#
#         var mainCatId = [];
# mainCatId.push(1)
# mainCatId.push(157)
# mainCatId.push(189)
# mainCatId.push(396)
# mainCatId.push(558)
# mainCatId.push(580)
# mainCatId.push(637)
# mainCatId.push(753)
# mainCatId.push(776)
# mainCatId.push(856)
# mainCatId.push(919)
# mainCatId.push(959)
# mainCatId.push(987)
# mainCatId.push(1019)
# mainCatId.push(1032)
# mainCatId.push(1063)
# mainCatId.push(1193)
# mainCatId.push(1207)
# mainCatId.push(1235)
# mainCatId.push(1254)
# mainCatId.push(1255)
# mainCatId.push(1256)
# mainCatId.push(1257)
# mainCatId.push(1258)
# mainCatId.push(1259)
# mainCatId.push(1260)
#
#
#
#     </script>
# <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@400;700&amp;display=swap" rel="stylesheet"/>
# <style type="text/css">
#         label.error {
#             position: absolute;
#             right: 15px;
#             margin-top: -25px;
#         }
#     </style>
# </link></head>
# <body>
# <div class="overlay-on-side"></div>
# <nav class="navbar navbar-expand-md py-0 border-bottom border-light">
# <a class="navbar-brand text-secondary big-header-text" href="/"><img src="/Content/images/v2/logo.png"/></a>
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="navbar-collapse collapse w-100 order-1 order-md-0 dual-collapse2">
# <ul class="navbar-nav mr-auto">
# <li class="nav-item">
# <a class="nav-link text-secondary smali-header-text" href="/Search?pageView=1">Сите огласи</a>
# </li>
# <li class="nav-item">
# <a class="nav-link text-secondary smali-header-text" href="/PremiumDetails/List">Продавници</a>
# </li>
# </ul>
# </div>
# <div class="mx-auto w-100 order-0" style="min-width: 400px">
# <ul class="navbar-nav">
# <li class="nav-item align-self-center">
# <span>
# <img src="/Content/images/no1.jpg"/>
# </span>
# <span class="smali-header-text" style="margin-left: 10px;margin-right: 10px;">
#                     302737 Огласи
#                 </span>
# </li>
# <li class="nav-item">
# <a class="nav-link text-secondary" href="/Register" style="padding-left:20px">
# <img height="35" src="/Content/images/circle_pen.jpg" style="float:left" width="35"/>
# <div class="d-inline text-right" style="float:left; padding-left:5px">
# <p class="mb-0 smali-header-text"> <small>Внеси нов оглас</small></p>
# <p class="text-danger mb-0 smali-header-text"><small>бесплатно</small></p>
# </div>
# </a>
# </li>
# </ul>
# </div>
# <div class="navbar-collapse collapse w-100 order-3 dual-collapse2">
# <ul class="navbar-nav ml-auto">
# <li class="nav-item">
# <a class="nav-link text-secondary big-header-text" href="/Help"><i class="far fa-question-circle"></i></a>
# </li>
# <li class="nav-item">
# </li>
# <li class="nav-item">
# <a class="nav-link text-secondary big-header-text" href="/Favorites"><i class="far fa-heart"></i></a>
# </li>
# <li class="nav-item">
# <a class="nav-link text-secondary big-header-text" href="#" onclick="showRightSidebar()"><i class="far fa-user-circle"></i></a>
# </li>
# </ul>
# </div>
# </nav>
# <div class="py-3 pl-0 pr-0 bg-white d-none sidebar-left">
# <ul class="list-unstyled" id="categories-container">
# <li class="text-secondary pr-3" style="padding-left:5px;">
# <i class="fas fa-circle mr-3 cat-level-circle" id="cat-level-circle0"></i><i class="far fa-circle mr-3 cat-level-circle" id="cat-level-circle1"></i><i class="far fa-circle mr-3 cat-level-circle" id="cat-level-circle2"></i><i class="far fa-circle cat-level-circle" id="cat-level-circle3"></i><i class="fas fa-times float-right" onclick="hideLeftSideMenu()" style="cursor:pointer;font-size:26px;"></i></li>
# <li></li>
# </ul>
# </div>
# <div class="bg-white d-none sidebar-right">
# <div class="w-100 border-bottom p-3" style="height:50px;">
# <a class="text-secondary float-left" href="#" onclick="hideRightSideMenu()"><i class="fas fa-times" style="font-size:22px"></i></a>
# </div>
# <div class="p-3">
# <form action="/Register/Login" id="frmLogin" method="post"><input name="__RequestVerificationToken" type="hidden" value="gJcIX_e8VWGzF6WEG6b04TDNrTOPDmTZGmhYvGagc0z5ChC_Xp1isLRo1Uvi7LHjaYJTw4woAuhLcmRZBMbdlzDbHcBmZ6FiuARqJ49Nizc1"/> <h5 class="text-center text-primary my-3">Најави се</h5>
# <p>
# <input class="form-control form-control-sm register-input" id="loginEmail" maxlength="100" name="loginEmail" placeholder="Е-Маил" type="text"/>
# </p>
# <p>
# <input class="form-control form-control-sm register-input" id="loginPassword" name="loginPassword" placeholder="Лозинка" type="password"/>
# </p>
# <div class="row">
# <div class="col-4 pr-0">
# <div class="form-check">
# <input checked="" class="form-check-input" id="chkRememberMe" name="chkRememberMe" type="checkbox" value="1"/>
# <label class="form-check-label" for="chkRememberMe">
# <small>Запомни ме</small>
# </label>
# </div>
# </div>
# <div class="col-8 text-right">
# <a class="btn btn-link btn-sm forgetPassBtn" href="/Register/ForgotPassword">Ја заборавивте лозинка?</a>
# </div>
# </div>
# <p>
# <input class="btn btn-primary btn-block mt-3" id="btnSubmit" type="submit" value="Најави се">
# </input></p>
# <p>
#
#             </p>
# </form>
# <form action="/Register/RegisterUser" id="frmRegister" method="post"><input name="__RequestVerificationToken" type="hidden" value="laGFFYCB5K6EIDlUzgmWqWlv7hMnM-KTkuaf-JZ8JVSl6Ff-AlTsl3iC_u3X3MFTvF_iBAS7UfTIseZuX9ClF3GLYj40wqYg1jLlnGPZFWw1"/> <div class="pt-5"></div>
# <h5 class="text-center text-primary">Регистрирај се</h5>
# <span class="text-secondary text-center">
# <small>*Верификацијата на профилот е задолжителна</small>
# </span>
# <div class="row mt-2">
# <div class="col-12">
# <div class="btn-group btn-group-toggle w-100" data-toggle="buttons">
# <label class="btn btn-outline-primary active">
# <input checked="" id="optLice" name="options" type="radio" value="0"/> Лице
#                         </label>
# <label class="btn btn-outline-primary">
# <input id="optPretprijatie" name="options" type="radio" value="1"/> Претпријатие
#                         </label>
# </div>
# </div>
# </div>
# <div class="pt-4"></div>
# <p>
# <input autocomplete="off" class="form-control form-control-sm register-input" id="regName" maxlength="60" name="regName" placeholder="Име" type="text">
# </input></p>
# <p>
# <select class="form-control form-control-sm register-input" id="regCity" name="regCity" onchange="CityOnChange(this.value)" placeholder="Одберете локација" style="margin-left:0px;"><option value="">Одбери Локација</option>
# <option value="1">Скопје</option>
# <option value="2">Битола</option>
# <option value="3">Куманово</option>
# <option value="4">Прилеп</option>
# <option value="5">Тетово</option>
# <option value="6">Велес</option>
# <option value="7">Штип</option>
# <option value="8">Охрид</option>
# <option value="9">Гостивар</option>
# <option value="10">Струмица</option>
# <option value="11">Кавадарци</option>
# <option value="12">Кочани</option>
# <option value="13">Кичево</option>
# <option value="14">Струга</option>
# <option value="15">Радовиш</option>
# <option value="16">Гевгелија</option>
# <option value="17">Дебар</option>
# <option value="18">Крива Паланка</option>
# <option value="19">Свети Николе</option>
# <option value="20">Неготино</option>
# <option value="21">Делчево</option>
# <option value="22">Виница</option>
# <option value="23">Ресен</option>
# <option value="24">Пробиштип</option>
# <option value="25">Берово</option>
# <option value="26">Кратово</option>
# <option value="28">Крушево</option>
# <option value="29">Македонски Брод</option>
# <option value="30">Валандово</option>
# <option value="34">Демир Хисар</option>
# </select>
# </p>
# <div id="divopstina" style="clear:both; padding:5px; display: none;"></div>
# <p id="popstina" style="display: none;">
# <select class="form-control form-control-sm register-input" id="regopstina" name="regOpstina">
# <option value="">Одбери Општина</option>
# </select>
# </p>
# <p>
# <input autocomplete="off" class="form-control form-control-sm register-input" id="regEmail" maxlength="60" name="regEmail" placeholder="Е-Маил" type="email">
# </input></p>
# <p>
# <input autocomplete="off" class="form-control form-control-sm register-input" id="regPhone" maxlength="30" name="regPhone" onkeyup="this.value=this.value.replace(/[^\d]/,'')" placeholder="Телефон" style="width:70%; float:left" type="text"/>
# <div style="float:left; margin-left:10px">
# <input class="form-check-input" id="chkViber" name="chkViber" style="width:15px; height:15px; margin-left:0" type="checkbox" value="1"/>
# <label class="fab fa-viber" for="chkViber" style="font-size:22px;color:#7360f2; margin-left:20px; margin-top:3px;"></label>
# </div>
# <div style="float:left; margin-left:15px;">
# <input class="form-check-input" id="chkWhatsup" name="chkWhatsup" style="width:15px; height:15px; margin-left:0" type="checkbox" value="1"/>
# <label class="fab fa-whatsapp" for="chkWhatsup" style="font-size:22px;color:#25D366; margin-left:20px; margin-top:3px;"></label>
# </div>
# </p>
# <p>
# <input autocomplete="off" class="form-control form-control-sm register-input" id="regPass" name="regPass" placeholder="Лозинка" type="password">
# </input></p>
# <p>
# <input autocomplete="off" class="form-control form-control-sm register-input" id="regPass2" name="regPass2" placeholder="Повтори лозинка" type="password">
# </input></p>
# <div class="pt-4"></div>
# <div class="form-check">
# <input checked="checked" class="form-check-input" id="chkAgree" name="chkAgree" type="checkbox" value="1"/>
# <label class="form-check-label" for="chkAgree">
# <small>Се согласувам и ги прифаќам <a href="/Help/HelpTerms">условите на употреба</a></small>
# </label>
# </div>
# <div class="form-check">
# <input checked="checked" class="form-check-input" id="chkAgreeNews" name="chkAgreeNews" type="checkbox" value="1"/>
# <label class="form-check-label" for="chkAgreeNews">
# <small>Се согласувам да добивам новости</small>
# </label>
# </div>
# <div style="clear:both; padding:5px"></div>
# <p>
#
#                 </p>
# <div class="pt-4"></div>
# <p class="text-left">
# <a class="btn btn-success btn-block text-white" id="btnRegister"><i class="fas fa-user-plus"></i> Регистрирај се </a>
# </p>
# </form> </div>
# </div>
# <div class="bg-white d-none sidebar-right-city">
# <div class="w-100 border-bottom p-3" style="height:62px;">
# <i class="fas fa-times" onclick="hideRightSideCityFilter()" style="cursor: pointer; font-size:26px; vertical-align: -6px; margin-right: 8px;"></i>
# <div class="d-inline-block text-right">
# <button class="btn btn-primary mr-2 pr-4 pl-4 buttonColor" onclick="filterCityClick()">Барај</button>
# <span><small>Можете да изберете повеќе градови</small></span>
# </div>
# </div>
# <div class="p-3">
# <div class="row mt-3 mb-5">
# <div class="col-12">
# <ul class="list-unstyled" id="cities-container">
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div></div>
# <!-- /21619973618/home-top-banner-970x90 -->
# <div id="div-gpt-ad-1505228250182-0" style="margin:auto;text-align: center;margin-bottom: 8px;">
# <script>
#             googletag.cmd.push(function () { googletag.display('div-gpt-ad-1505228250182-0'); });
#         </script>
# </div>
# <form action="/Search" id="myFrom" method="get" novalidate="novalidate">
# <input id="city" name="city" type="hidden">
# <input id="cat" name="cat" type="hidden">
# <div class="text-center clear-padding" style="margin:auto; top:15px; z-index:999; position:relative; display:table">
# <div class="text-center lrpadding_5 search-box-position-fix">
# <div class="dropdown" onclick="showLeftSidebar()">
# <div class="form-control" data-target="#" href="" id="dLabel" role="button" style="border-radius:20px 0px 0px 20px; cursor:pointer; padding: 4px 3px; width:330px; height:35px; text-align:left; text-overflow:ellipsis; overflow:hidden; white-space:nowrap"><embed src="/Content/images/v2/menu.svg" style="width:28px; float:left; padding:5px" type="image/svg+xml"/><span class="search-box-font" id="site_name" style="float:left; max-width:220px; overflow:hidden; position:relative; top:2px; margin-left:10px;">Сите Категории</span> <span class="caret" style="float:right; margin-right:5px; margin-top:10px"></span></div>
# </div>
# </div>
# <div class="text-center search-box-position-fix">
# <input class="form-control search-box-font" id="q" name="q" placeholder="BMW, Iphone, Samsung, Оглас број" style="height:35px; width:330px;border-radius:0px; " type="text"/>
# </div>
# <div class="text-center lrpadding_5 search-box-position-fix" onclick="showRightSidebarCityFilter()">
# <div class="form-control" data-target="#" href="" style="cursor:pointer; border-radius:0px; padding: 4px 3px; width:330px;height:35px; text-align:left; text-overflow:ellipsis; overflow:hidden; white-space:nowrap"><embed src="/Content/images/v2/lokation.svg" style="width:28px; float:left; padding:5px" type="image/svg+xml"/><span class="search-box-font" id="site_name" style="float:left; max-width:220px; overflow:hidden; position:relative; top:2px; margin-left:10px;">Цела Македонија</span> <span class="caret" style="float:right; margin-right:5px; margin-top:10px"></span></div>
# </div>
# <div class="text-center lrpadding_5 search-box-position-fix">
# <div class="btn btn-xs btn-primary" id="btnHomeSearch" name="btnHomeSearch" onclick="doSearch();" style="border-radius: 0px 20px 20px 0px; height:35px; width:100px; padding:0">
# <embed src="/Content/images/v2/search_w.svg" style="margin:auto; width:40px; padding:5px" type="image/svg+xml"/>
# </div>
# </div>
# </div>
# </input></input></form>
# <div class="clear-20"></div>
# <div class="clear-5"></div>
# <div class="col-md-12" style="padding:0 16px 0 16px">
# <div class="promoeted-ads">
# <a class="ad-promoted-link ad-container r5-slider col-md-2" data-adid="4187766" data-index="0" href="/AdDetails?ad=4187766" style="display:inline-flex">
# <div class="card ad-tumbnail">
# <div class="ad-info-container">
# <img height="0px" src="//stats.reklama5.mk/pixel.gif?fkType=0&amp;fkNum=4187766&amp;type=imp" style="display:none" widht="0px'"/>
# <div class="ad-image" style="background-image:url(//reklama5.mk/photos/big/ffe94bed-ae0f-446d-8197-6f43eac2abc2.jpg)"></div>
# <div class="r5-slider-prev">
# <i aria-hidden="true" class="fa fa-angle-left"></i>
# </div>
# <div class="r5-slider-next">
# <i aria-hidden="true" class="fa fa-angle-right"></i>
# </div>
# <div class="ad-image-text">
# <span><small><i aria-hidden="true" class="fa fa-map-marker"></i> Карпош</small></span>
# <span style="float:right">
# <small>Денес 13:00</small>
# </span>
# </div>
# </div>
# <div class="ad-promoted-link" href="/AdDetails?ad=4187766">
# <div class="card-body ad-promo-caption">
# <h5>NAJDOBROTO PLAKANJE ZA VOZACI 13.5centi/KM poln/prazen</h5>
# <h3>0 €</h3>
# </div>
# </div>
# </div>
# </a>
# <a class="ad-promoted-link ad-container r5-slider col-md-2" data-adid="4466986" data-index="0" href="/AdDetails?ad=4466986" style="display:inline-flex">
# <div class="card ad-tumbnail">
# <div class="ad-info-container">
# <img height="0px" src="//stats.reklama5.mk/pixel.gif?fkType=0&amp;fkNum=4466986&amp;type=imp" style="display:none" widht="0px'"/>
# <div class="ad-image" style="background-image:url(//reklama5.mk/photos/big/65efa535-5cbd-4cc6-931f-6fd4588cc2b5.jpg)"></div>
# <div class="r5-slider-prev">
# <i aria-hidden="true" class="fa fa-angle-left"></i>
# </div>
# <div class="r5-slider-next">
# <i aria-hidden="true" class="fa fa-angle-right"></i>
# </div>
# <div class="ad-image-text">
# <span><small><i aria-hidden="true" class="fa fa-map-marker"></i> Скопје Центар</small></span>
# <span style="float:right">
# <small>Денес 13:00</small>
# </span>
# </div>
# </div>
# <div class="ad-promoted-link" href="/AdDetails?ad=4466986">
# <div class="card-body ad-promo-caption">
# <h5>R 1250 GS hp</h5>
# <h3>18000 €</h3>
# </div>
# </div>
# </div>
# </a>
# <a class="ad-promoted-link ad-container r5-slider col-md-2" data-adid="4128354" data-index="0" href="/AdDetails?ad=4128354" style="display:inline-flex">
# <div class="card ad-tumbnail">
# <div class="ad-info-container">
# <img height="0px" src="//stats.reklama5.mk/pixel.gif?fkType=0&amp;fkNum=4128354&amp;type=imp" style="display:none" widht="0px'"/>
# <div class="ad-image" style="background-image:url(//reklama5.mk/photos/big/16df3071-85a2-4f8b-b01b-104c173d9d2e.jpg)"></div>
# <div class="r5-slider-prev">
# <i aria-hidden="true" class="fa fa-angle-left"></i>
# </div>
# <div class="r5-slider-next">
# <i aria-hidden="true" class="fa fa-angle-right"></i>
# </div>
# <div class="ad-image-text">
# <span><small><i aria-hidden="true" class="fa fa-map-marker"></i> Прилеп</small></span>
# <span style="float:right">
# <small>03/10/2022 19:45</small>
# </span>
# </div>
# </div>
# <div class="ad-promoted-link" href="/AdDetails?ad=4128354">
# <div class="card-body ad-promo-caption">
# <h5>Podno greenje pod tepih</h5>
# <h3>15 €</h3>
# </div>
# </div>
# </div>
# </a>
# <a class="ad-promoted-link ad-container r5-slider col-md-2" data-adid="3721638" data-index="0" href="/AdDetails?ad=3721638" style="display:inline-flex">
# <div class="card ad-tumbnail">
# <div class="ad-info-container">
# <img height="0px" src="//stats.reklama5.mk/pixel.gif?fkType=0&amp;fkNum=3721638&amp;type=imp" style="display:none" widht="0px'"/>
# <div class="ad-image" style="background-image:url(//reklama5.mk/photos/big/504e8a62-1fcb-4156-a9d4-ed640a682a7a.jpg)"></div>
# <div class="r5-slider-prev">
# <i aria-hidden="true" class="fa fa-angle-left"></i>
# </div>
# <div class="r5-slider-next">
# <i aria-hidden="true" class="fa fa-angle-right"></i>
# </div>
# <div class="ad-image-text">
# <span><small><i aria-hidden="true" class="fa fa-map-marker"></i>
# ...
# <script src="/Scripts/search.js"></script>
# <script type="text/javascript">
#
#       $(function () {
#           $('.map').maphilight();
#           $('.cities-title').parent().css('margin-bottom', '1px !important');
#       });
#     function newImage(arg) {
#       if (document.images) {
#         rslt = new Image();
#         rslt.src = arg;
#         return rslt;
#       }
#     }
#
#     function changeImages() {
#       preloadImages();
#       if (document.images && (preloadFlag == true)) {
#         for (var i = 0; i < changeImages.arguments.length; i += 2) {
#           document.getElementById([changeImages.arguments[i]]).src = changeImages.arguments[i + 1];
#         }
#       }
#     }
#
#     var preloadFlag = false;
#     function preloadImages() {
#       if (document.images) {
#         img1 = newImage("../Content/images/map2/1.gif");
#         img2 = newImage("../Content/images/map2/2.gif");
#         img3 = newImage("../Content/images/map2/3.gif");
#         img4 = newImage("../Content/images/map2/4.gif");
#         img5 = newImage("../Content/images/map2/5.gif");
#         img6 = newImage("../Content/images/map2/6.gif");
#         img7 = newImage("../Content/images/map2/7.gif");
#         img8 = newImage("../Content/images/map2/8.gif");
#         img9 = newImage("../Content/images/map2/9.gif");
#         img10 = newImage("../Content/images/map2/10.gif");
#         img11 = newImage("../Content/images/map2/11.gif");
#         img12 = newImage("../Content/images/map2/12.gif");
#         img13 = newImage("../Content/images/map2/13.gif");
#         img14 = newImage("../Content/images/map2/14.gif");
#         img15 = newImage("../Content/images/map2/15.gif");
#         img16 = newImage("../Content/images/map2/16.gif");
#         img17 = newImage("../Content/images/map2/17.gif");
#         img18 = newImage("../Content/images/map2/18.gif");
#         img19 = newImage("../Content/images/map2/19.gif");
#         img20 = newImage("../Content/images/map2/20.gif");
#         img21 = newImage("../Content/images/map2/21.gif");
#         img22 = newImage("../Content/images/map2/22.gif");
#         img23 = newImage("../Content/images/map2/23.gif");
#         img24 = newImage("../Content/images/map2/24.gif");
#         img25 = newImage("../Content/images/map2/25.gif");
#         img26 = newImage("../Content/images/map2/26.gif");
#         img28 = newImage("../Content/images/map2/28.gif");
#         img29 = newImage("../Content/images/map2/29.gif");
#         img30 = newImage("../Content/images/map2/30.gif");
#         preloadFlag = true;
#       }
#     }
#   </script>
# <script async="async" src="https://platform-api.sharethis.com/js/sharethis.js#property=5ea93e34ff8d72001157bc39&amp;product=inline-share-buttons" type="text/javascript"></script>
# <script type="text/javascript">
#         $(document).ready(function () {
#             $('#regName').tooltip({ 'trigger': 'focus', 'html': 'true', 'title': '<div style="width:150px;">Внесете го Вашето Име</div>', 'placement': 'right' });
#             $('#regCity').tooltip({ 'trigger': 'focus', 'html': 'true', 'title': '<div style="width:300px;">Најчесто огласувачот го одбира оној град во кој се наоѓа предметот/тој сака предметот да биде локализиран.</div>', 'placement': 'right' });
#             $('#regEmail').tooltip({ 'trigger': 'focus', 'html': 'true', 'title': '<div style="width:300px;">Ве молиме внесете валиден Е-Маил. Профили со невалидни Е-Маил адреси ќе бидат избришани.</div>', 'placement': 'right' });
#             $('#regPhone').tooltip({ 'trigger': 'focus', 'html': 'true', 'title': '<div style="width:250px;">Внесете го Вашиот телефонски број.</div>', 'placement': 'right' });
#             $('#regPass').tooltip({ 'trigger': 'focus', 'html': 'true', 'title': '<div style="width:300px;">Избегнувајте употреба на истата лозинка која ја користите и за други веб страници. Чувајте ја вашата лозинка во тајност и не ја делете со другите.</div>', 'placement': 'right' });
#             $('#regPass2').tooltip({ 'trigger': 'focus', 'html': 'true', 'title': '<div style="width:150px;">Повторете ја лозинката.</div>', 'placement': 'right' });
#             //checkStatus('optLice');
#         });
#         $(document).ready(function () {
#             if (!$.cookie('cookiesAgreed')) {
#                 $('#cookiePopup').show(0);
#             }
#         });
#
#         var opstiniArray = [[267, 1, 'Скопје Центар', 41.978187, 21.427388],[268, 1, 'Карпош', 41.991502, 21.39781],[269, 1, 'Кисела Вода', 41.931839, 21.502835],[270, 1, 'Аеродром', 41.949632, 21.502494],[271, 1, 'Гази Баба', 42.00877, 21.45126],[272, 1, 'Бутел', 42.052075, 21.450415],[273, 1, 'Чаир', 41.993825, 21.436139],[274, 1, 'Ѓорче Петров', 42.013646, 21.32586],[275, 1, 'Сарај', 41.999359, 21.327548],[276, 1, 'Шуто Оризари', 42.036516, 21.42584],[277, 1, 'Сопиште', 41.944583, 21.395116],[278, 1, 'Студеничани', 41.922679, 21.536229],[279, 1, 'Зелениково', 41.873242, 21.601714],[280, 1, 'Петровец', 41.93375, 21.621843],[281, 1, 'Илинден', 41.989867, 21.581912],[282, 1, 'Арачиново', 42.026658, 21.562729],[283, 1, 'Чучер Сандево', 42.096995, 21.388571],[284, 1, 'Автокоманда', 42.003425, 21.463615],[285, 2, 'Битола', 41.031728, 21.329358],[286, 2, 'Могила', 41.17531, 21.394995],[287, 2, 'Новаци', 41.045021, 21.462461],[288, 3, 'Куманово', 42.132926, 21.715878],[289, 3, 'Старо Нагоричане', 42.198776, 21.835265],[290, 3, 'Ранковце', 42.183229, 22.093498],[291, 4, 'Прилеп', 41.346182, 21.553379],[292, 4, 'Кривогаштани', 41.337355, 21.33078],[293, 4, 'Долнени', 41.425943, 21.453794],[294, 5, 'Тетово', 42.009423, 20.971549],[295, 5, 'Боговиње', 41.923402, 20.916068],[296, 5, 'Теарце', 42.077699, 21.053594],[297, 5, 'Јегуновце', 42.073867, 21.118206],[298, 5, 'Брвеница', 41.967228, 20.980786],[299, 5, 'Желино', 41.982516, 21.062434],[300, 6, 'Велес', 41.715954, 21.770997],[301, 6, 'Чашка', 41.64664, 21.691839],[302, 6, 'Градско', 41.576175, 21.948139],[303, 7, 'Штип', 41.745515, 22.19396],[304, 7, 'Карбинци', 41.815793, 22.236264],[305, 8, 'Охрид', 41.111733, 20.798579],[306, 8, 'Дебарца', 41.218558, 20.763343],[307, 9, 'Гостивар', 41.801881, 20.913259],[308, 9, 'Врапчиште', 41.834089, 20.883743],[309, 9, 'Маврово и Ростуша', 41.651396, 20.735753],[310, 10, 'Струмица', 41.440569, 22.639528],[311, 10, 'Василево', 41.475581, 22.643096],[312, 10, 'Босилово', 41.438738, 22.729228],[313, 10, 'Ново Село', 41.411372, 22.879678],[314, 11, 'Кавадарци', 41.438304, 22.004864],[315, 11, 'Росоман', 41.515718, 21.949554],[316, 12, 'Кочани', 41.924335, 22.404964],[317, 12, 'Чешиново', 41.873525, 22.29332],[318, 14, 'Струга', 41.173346, 20.677493],[319, 14, 'Вевчани', 41.240371, 20.592708],[320, 15, 'Радовиш', 41.635743, 22.470056],[321, 15, 'Конче', 41.495774, 22.385457],[322, 16, 'Гевгелија', 41.14712, 22.507161],[323, 16, 'Богданци', 41.202685, 22.574287],[324, 16, 'Дојран', 41.233523, 22.693527],[325, 17, 'Дебар', 41.516028, 20.533415],[326, 17, 'Центар Жупа', 41.477926, 20.559269],[327, 18, 'Крива Паланка', 42.205478, 22.333429],[328, 18, 'Ранковце', 42.167713, 22.117538],[329, 19, 'Свети Николе', 41.865485, 21.940845],[330, 19, 'Лозово', 41.781495, 21.907623],[331, 20, 'Неготино', 41.484224, 22.089622],[332, 20, 'Демир Капија', 41.4085, 22.239783],[333, 21, 'Делчево', 41.966811, 22.781396],[334, 21, 'Македонска Каменица', 42.015547, 22.589189],[335, 22, 'Виница', 41.884235, 22.515181],[336, 22, 'Зрновци', 41.855809, 22.450171],[337, 25, 'Берово', 41.711096, 22.848172],[338, 25, 'Пехчево', 41.760482, 22.885484],[339, 28, 'Крушево', 41.373181, 21.252891],[340, 28, 'Пласница', 41.470992, 21.125035]];
#
#         function CityOnChange(cityId) {
#             $("#regopstina").clearSelect();
#             var ddlOpstina = document.getElementById('regopstina');
#             opt = document.createElement("option");
#             opt.value = "";
#             opt.text = "Одберете Општина";
#             ddlOpstina.appendChild(opt);
#             var opstinaFound = false;
#             $.each(opstiniArray, function (index, optionData) {
#                 if (optionData[1] == cityId) {
#                     opt = document.createElement("option");
#                     opt.value = optionData[0];
#                     opt.text = optionData[2];
#                     ddlOpstina.appendChild(opt);
#                     opstinaFound = true;
#                 }
#             });
#
#             if (opstinaFound == false) {
#                 $("#popstina").hide();
#                 $("#divopstina").hide();
#             }
#             else {
#                 $("#popstina").show();
#                 $("#divopstina").show();
#             }
#
#         }
#
#         $.fn.clearSelect = function () {
#             return this.each(function () {
#                 if (this.tagName == 'SELECT')
#                     this.options.length = 0;
#             });
#         }
#     </script>
# <script type="text/javascript">
#         $(document).ready(function () {
#
#             var frmLogin = $('#frmLogin').get(0);
#             $.removeData(frmLogin, 'validator');
#             var frmRegister = $('#frmRegister').get(0);
#             $.removeData(frmRegister, 'validator');
#
#             $('#frmLogin').validate(
#               {
#                   rules: {
#                       loginEmail: {
#                           required: true,
#                           email: true
#                       },
#                       loginPassword: "required",
#                   },
#                   messages: {
#                       loginEmail: {
#                           required: "<span class='fa fa-ban errorIcon' style='font-size:12px;'></span>",
#                           email: "<span class='fa fa-ban errorIcon' style='font-size:12px;'></span>"
#                       },
#                       loginPassword: "<span class='fa fa-ban errorIcon' style='font-size:12px;'></span>"
#                   }
#               });
#
#             $('#frmRegister').validate(
#               {
#                   rules: {
#                       regName: "required",
#                       regCity: "required",
#                       regOpstina: "required",
#                       regEmail: {
#                           required: true,
#                           email: true
#                       },
#                       regPhone: "required",
#                       regPass: "required",
#                       regPass2: {
#                           required: true,
#                           equalTo: "#regPass"
#                       }
#
#                   },
#                   messages: {
#                       regName: "<span class='fa fa-ban errorIcon' style='font-size:12px;'></span>",
#                       regEmail: {
#                           required: "<span class='fa fa-ban errorIcon' style='font-size:12px;'></span>",
#                           email: "<span class='fa fa-ban errorIcon' style='font-size:12px;'></span>"
#                       },
#                       regCity: "<span class='fa fa-ban errorIcon' style='font-size:12px;'></span>",
#                       regOpstina: "<span class='fa fa-ban errorIcon' style='font-size:12px;'></span>",
#                       regPhone: "<span class='fa fa-ban errorIcon' style='font-size:12px;'></span>",
#                       regPass: "<span class='fa fa-ban errorIcon' style='font-size:12px;'></span>",
#                       regPass2: {
#                           required: "<span class='fa fa-ban errorIcon' style='font-size:12px;'></span>",
#                           equalTo: "<span class='fa fa-ban errorIcon' style='font-size:12px;'></span>"
#                       }
#                   }
#               });
#
#
#         });
#
#         function cookiesAgreed() {
#             $.cookie('cookiesAgreed', "1", { expires: 365, path: '/', domain: cookieDomain });
#             $('#cookiePopup').hide(0);
#         }
#
#         $('#btnSubmit').click(function () {
#             if ($('#frmLogin').valid()) {
#                 $('#btnSubmit').attr('disabled', 'disabled');
#                 document.getElementById('frmLogin').submit();
#             }
#             return false;
#         });
#
#         $('#btnRegister').click(function () {
#             var tos = $('#chkAgree');
#             if (!tos.is(":checked")) {
#                 alert('Мора да се согласите со правилата за да може да се регистрирате');
#             }
#             else {
#                 if ($('#frmRegister').valid()) {
#                     $('#btnRegister').attr('disabled', 'disabled');
#                     document.getElementById('frmRegister').submit();
#                 }
#                 return false;
#             }
#         });
#     </script>
# <script type="text/javascript">
#         var bannerCategories = [24, 157, 189, 396, 558, 580, 1032, 1207, 1256];
#         function doSearch() {
#             if (document.getElementById("myFrom")) document.getElementById('myFrom').submit();
#         }
#         $(document).ready(function () {
#             //$('.promoeted-ads').slick({
#             //    autoplay: false,
#             //    autoplaySpeed: 3000,
#             //    dots: false,
#             //    infinite: true,
#             //    //slidesToShow: 1,
#             //    speed: 300,
#             //    //slickPause: true,
#             //    variableWidth: true,
#             //    //slidesToScroll: 1
#             //});
#
#             //$('.search-bar-holder').data('rank', 1);
#             //$('.category-circle-link[data-rank="' + 1 + '"]').addClass("active");
#             //setInterval(function () {
#             //    var rank = $('.search-bar-holder').data('rank');
#             //    rank++;
#             //    if (rank == 10) rank = 1;
#             //    var imageUrl = "url(/Content/images/categories/cover/k" + bannerCategories[rank - 1] + ".jpg)";
#             //    $('.search-bar-holder').data('rank', rank)
#             //    $(".search-bar-holder").fadeOut(50, function () {
#             //        $(this).css("background-image", imageUrl);
#             //        $(this).fadeIn();
#             //    });
#             //    $('.category-circle-link').removeClass("active");
#             //    $('.category-circle-link[data-rank="'+ rank + '"]').addClass("active");
#             //}, 5000)
#             //$('.category-circle-link').hover(function () {
#             //    var currentRank = $('.search-bar-holder').data('rank');
#             //    var rank = $(this).data('rank');
#             //    $('.search-bar-holder').data('rank', rank)
#             //    $('.category-circle-link').removeClass("active");
#             //    $(this).addClass("active");
#             //    var imageUrl = "url(/Content/images/categories/cover/k" + bannerCategories[rank-1] + ".jpg)";
#             //    if (currentRank != rank)
#             //        $(".search-bar-holder").fadeOut(50, function () {
#             //            $(this).css("background-image", imageUrl);
#             //            $(this).fadeIn();
#             //        });
#             //});
#             //$('.search-bar-holder').click(function () {
#             //    var rank = $(this).data('rank');
#             //    window.location = $('.category-circle-link[data-rank="' + rank + '"]').attr('href')
#             //});
#         });
#     </script>
# <script src="/bundles/master-home?v=dQ5_KTCJEeUR_PgOCXUwLKxxXxVRLYz6MzplTz3syL01"></script>
# <noscript><img alt="" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=U/aNh1awVK00Oo" style="display: none" width="1"/></noscript>
# <div id="cookiePopup" style="width:100%; background-color:#fff; height:130px; position:fixed; bottom:0">
# <div style="width:65%; margin:auto; padding:20px 0 20px 0; display:table; position:relative">
# <div style="float:left; width:80%">
# <p style="font-size:20px; font-weight:bold">Добредојдовте на Reklama5.mk</p>
# <p>Со цел да ја направиме Реклама5 полесна и подостапна за употреба, ние користиме cookies на нашата веб страница. Со сурфање на reklama5.mk се согласувате да користите колачиња. Детални информации можете да најдете на <a href="/Help/HelpTerms#cookies">Политика за колачиња</a> </p>
# </div>
# <div style="float:right; margin-top:35px">
# <div class="btn btn-xs btn-primary" onclick="cookiesAgreed();" style="cursor:pointer">Се согласувам</div>
# </div>
# </div>
# </div>
# </body>
# </html>

# %% [markdown]
# # <font color='Orange'>Extracting data</font>

# %% [markdown]
# From the printed HTML code search for the data you need for building the dataset, find the classes for groupby option.
#
# **In the following text-box write the attributes you are going to use**

# %% [markdown]
# <font color='red'> You need to extract a minimum of four features (lists/columns) from the web site (example: titles, posting time, comments, likes, ...)</font>

# %% [markdown]
# `add your attributes here for building the dataset`

# %% [markdown]
# **Try to select the first element from your attributes. Find out from the html code what part do you need.**

# %%
#add your code
card_caption = soup.select_one('.ad-promo-caption')
card_caption
HTML(card_caption.prettify())
# Out:
# <div class="card-body ad-promo-caption">
#  <h5>
#   NAJDOBROTO PLAKANJE ZA VOZACI 13.5centi/KM poln/prazen
#  </h5>
#  <h3>
#   0 €
#  </h3>
# </div>

# %% [markdown]
# **Add as many codeboxes as you need for selecting all the html elements**

# %%
#add your code
ad_captions = soup.select('.ad-promo-caption h5')
ad_prices = soup.select('.ad-promo-caption h3')
ad_timeandplace = soup.select('.ad-image-text small')

# %% [markdown]
# **Create lists with the extracted data from the html elements that you selected**

# %%
#add your code
products = []
for caption in ad_captions:
  products.append(caption.text)

prices = []
for price in ad_prices:
  prices.append(price.text)

timeandplace = []
for tp in ad_timeandplace:
  timeandplace.append(tp.text)

place = []
place = timeandplace[::2]

time = []
time = timeandplace[1:len(timeandplace):2]

# %% [markdown]
# **Print all lists that are containing the elements**

# %%
#add your code
print(products)
print("\n")
print(prices)
print("\n")
print(time)
print("\n")
print(place)
# Out:
# ['NAJDOBROTO PLAKANJE ZA VOZACI 13.5centi/KM poln/prazen', 'R 1250 GS hp', 'Podno greenje pod tepih', 'gumi  Off Road  4x4  ', 'NOV STAN SO IMOTEN LIST VO GJORCE', 'Scirocco edinstveno so vakva oprema vo makedonija ', 'KIPERI MAN 4 OSOVINI TGA F2000', 'Bmw X6 M-Paket ', 'VW PASSAT HIGHLINE 8V 2.0 140ks 2007god', 'Prodavam ATV 250 cc', 'SKODA FABIA 2016 NEUVEZUVANA', 'Продажба на Нови и Половни Авто Делови За Сите Возила']
#
#
# ['0 €', '18000 €', '15 €', '1 €', '62000 €', '1 €', '1 €', '32000 €', '6100 €', '1800 €', '7490 €', '0 €']
#
#
# ['Денес 13:00', 'Денес 13:00', '03/10/2022 19:45', 'Денес 11:03', 'Денес 13:00', 'Денес 13:00', '19/10/2022 18:44', '15/10/2022 16:38', '14/10/2022 21:44', '22/10/2022 22:05', 'Денес 13:00', '25/10/2022 08:45']
#
#
# [' Карпош', ' Скопје Центар', ' Прилеп', ' Струмица', ' Ѓорче Петров', ' Скопје Центар', ' Прилеп', ' Тетово', ' Кочани', ' Кочани', ' Карпош', ' Битола']

# %% [markdown]
# **Check if all lists are the same size**

# %%
#add your code
len(products) == len(prices) == len(time) == len(place)
# Out:
# True

# %% [markdown]
# # <font color='Orange'>Create a Pandas DataFrame</font>

# %% [markdown]
# **Create the DataFrame from the lists you get and name your *Columns***

# %%
#add your code
matrix = []
for i in range(0, len(products)):
  matrix.append([products[i], prices[i], time[i], place[i]])
matrix = np.array(matrix)
matrix = {'Ad Product name': products, 'Product price': prices, 'Place': place, 'Time': time}
df = pd.DataFrame(matrix)

# %% [markdown]
# **Print the dataset you obtain**

# %%
#add your code
df
# Out:
#                                       Ad Product name Product price  \
# 0   NAJDOBROTO PLAKANJE ZA VOZACI 13.5centi/KM pol...           0 €
# 1                                        R 1250 GS hp       18000 €
# 2                             Podno greenje pod tepih          15 €
# 3                               gumi  Off Road  4x4             1 €
# 4                   NOV STAN SO IMOTEN LIST VO GJORCE       62000 €
# 5   Scirocco edinstveno so vakva oprema vo makedon...           1 €
# 6                      KIPERI MAN 4 OSOVINI TGA F2000           1 €
# 7                                     Bmw X6 M-Paket        32000 €
# 8             VW PASSAT HIGHLINE 8V 2.0 140ks 2007god        6100 €
# 9                                 Prodavam ATV 250 cc        1800 €
# 10                       SKODA FABIA 2016 NEUVEZUVANA        7490 €
# 11  Продажба на Нови и Половни Авто Делови За Сите...           0 €
#
#              Place              Time
# 0           Карпош       Денес 13:00
# 1    Скопје Центар       Денес 13:00
# 2           Прилеп  03/10/2022 19:45
# 3         Струмица       Денес 11:03
# 4     Ѓорче Петров       Денес 13:00
# 5    Скопје Центар       Денес 13:00
# 6           Прилеп  19/10/2022 18:44
# 7           Тетово  15/10/2022 16:38
# 8           Кочани  14/10/2022 21:44
# 9           Кочани  22/10/2022 22:05
# 10          Карпош       Денес 13:00
# 11          Битола  25/10/2022 08:45

# %% [markdown]
# # <font color = 'Green'>Advanced part</font>
#
# <font color = 'orange'>This part is not mandatory and is intended for those who want to expand their knowledge in this field</font>

# %% [markdown]
# There are other libraries in Python that can be used to scrape a website. Some examples are Scrapy (https://scrapy.org/) and Selenium (https://selenium-python.readthedocs.io/).

# %% [markdown]
# ## <font color = 'Green'>Extra task 1: Selenium</font>
# For the extra task you will need to take a look of the Selenium library. Here is a quick intro to this library and what features it has.
#
# Selenium is a robust framework designed to automate tests for Web Applications. It provides a way for the developer to write tests in several popular programming languages such as C#, Java, Python, Ruby, etc. This framework is developed to perform browser automation. Selenium is an excellent choice when you want to deal with Core Javascript-based web Applications and make browser automation with AJAX/PJAX Requests.
#
# View these links for more details:
#
# *   https://selenium-python.readthedocs.io/installation.html
# *   https://selenium-python.readthedocs.io/getting-started.html
# *   https://pypi.org/project/selenium-requests/
# *   https://pypi.org/project/selenium-wire/
#
# Starting code id given below.
#
# <font color ="red"> During the laboratory exercise, will be defined which side and what will need to be extracted using Selenium library</font>

# %%
#requirements for colab
# install chromium, its driver, and selenium
# !apt update
# !apt install chromium-chromedriver
# !pip install selenium
# set options to be headless, ..
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
# open it, go to a website, and get results
wd = webdriver.Chrome(options=options)
wd.get("https://www.website.com")
print(wd.page_source)  # results
#divs = wd.find_element(By.TAG_NAME, 'div')
